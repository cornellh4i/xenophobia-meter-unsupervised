# %% [markdown]
# # Script for Scraping German Tweets
# Description:
# to be written
#
# https://twitter.com/afd
# https://python.plainenglish.io/scraping-tweets-with-tweepy-python-59413046e788
# https://www.tweepy.org/

# %%
from tweepy import OAuthHandler
from tweepy.client import Client
import tweepy
import json
import pandas as pd
import csv
import re
from textblob import TextBlob
import string
import preprocessor as p
import os
import time
import re
from googletrans import Translator as trans

# %%
# keys to access Twitter API - need to put in env
api_key = "rrvwmzwkhv2g8ojhvLXzqpGiI"
api_secret = "K4RBhsY33EHe9uZkoLs1dr3fUJHEkIQpvCDCTJ3ekoj7Xi5u23"
bearer_token = "AAAAAAAAAAAAAAAAAAAAAJXXjAEAAAAAH2oj95GT6kjAqynSMXP%2FIH4W2hY%3DNuYn8xWm8VpkZ5HngtQLq4n28LLhRHNMPHkOVCBZNg4oreZSA0"

access_token = "1445822502878449668-Nsd4YAZXmMyQeAhvyGmZSf8zdjRJFn"
access_secret = "nk2C0D0kNNFkRH9viCbi0JSLAkvjW3I88RdRBXpBOblP9"

# passing keys to Tweepy - I think deprecated, use next two lines only for 1.1
auth = OAuthHandler(api_key, api_secret)
auth.set_access_token(access_token, access_secret)

client = tweepy.Client(bearer_token)

# %%
# get tweets from specific user - in this case, AFD. id was produced using https://tweeterid.com/
user_id = 844081278
tweets = client.get_users_tweets(id = user_id, max_results = 100)

# %%
# tweet dictionary
twts = {}
index = 0

# %%
# printing tweets
for t in tweets.data:
#     removing links
    t = re.sub(r'(https?:\/\/)?([\da-z\.-]+)\.([a-z\.]{2,6})([\/\w \.-]*)', '', str(t))
#     removing hashtags and RT
    t = re.sub(r'#\w*|RT\w*', '', t)
#     removing non-alpha characters
    tweet_split = re.sub(r'([^\s\w]|_)+|https\w*', '', t).split()[1:]
    twts[index] = tweet_split
    print(twts[index])
    index += 1
# Out:
# RT @M_Reichardt_AfD: Die Bürger sollen frieren und den Gürtel enger Schnallen und der aufgedunsene Versager-Wirtschaftsminister möchte für…
# ['Die', 'Brger', 'sollen', 'frieren', 'und', 'den', 'Grtel', 'enger', 'Schnallen', 'und', 'der', 'aufgedunsene', 'Versager-Wirtschaftsminister', 'mchte', 'fr']
# #Robert #Habeck will #Fotografen für 400.000 € - wir wollen echte #Volksvertreter! #UnserLandzuerst #AfD
#
# Eitelkeit rangiert vor Expertise, #Ideologie vor Integrität, Schaumschlägerei vor Sachpolitik. Es wird höchste Zeit für ein #Abschiedsfoto!
#
# https://t.co/dM8l1hSafy https://t.co/vNpWB0jieE
# ['fr', '-', 'wir', 'wollen', 'echte', 'Eitelkeit', 'rangiert', 'vor', 'Expertise', 'vor', 'Integritt', 'Schaumschlgerei', 'vor', 'Sachpolitik', 'Es', 'wird', 'hchste', 'Zeit', 'fr', 'ein']
# RT @Dennis_Hohloch: Als erster #AfD-Abgeordneter wurde ich heute mit Stimmen der @AfD_FraktionBB und weiterer Fraktionen im Landtag zum Mit…
# ['Als', 'erster', '-Abgeordneter', 'wurde', 'ich', 'heute', 'mit', 'Stimmen', 'der', 'AfDFraktionBB', 'und', 'weiterer', 'Fraktionen', 'im', 'Landtag', 'zum', 'Mit']
# RT @Dennis_Hohloch: U-Ausschüsse #Corona und #rbb im Landtag beschlossen. 💪
# https://t.co/qKZxnYlpT0
# ['U-Ausschsse', 'und', 'im', 'Landtag', 'beschlossen']
# RT @Tino_Chrupalla: Gestern ist offenbar eine Flugabwehrrakete der Ukraine in Polen eingeschlagen. Die Aufregung danach hat gezeigt: Falsch…
# ['Gestern', 'ist', 'offenbar', 'eine', 'Flugabwehrrakete', 'der', 'Ukraine', 'in', 'Polen', 'eingeschlagen', 'Die', 'Aufregung', 'danach', 'hat', 'gezeigt', 'Falsch']
# RT @Alice_Weidel: Die #Ampel macht #Deutschland arm: Mittlerweile gelten 15,8 Prozent der Bevölkerung als "arm". Das sind 13 Millionen Bürg…
# ['Die', 'macht', 'arm', 'Mittlerweile', 'gelten', 'Prozent', 'der', 'Bevlkerung', 'als', 'arm', 'Das', 'sind', 'Millionen', 'Brg']
# RT @KrahMax: Heute hoher Besuch auf dem Sächsischen Weihnachtsmarkt der Landesvertretung #Sachsen in Brüssel: @Tino_Chrupalla. Sachsen ist…
# ['Heute', 'hoher', 'Besuch', 'auf', 'dem', 'Schsischen', 'Weihnachtsmarkt', 'der', 'Landesvertretung', 'in', 'Brssel', 'TinoChrupalla', 'Sachsen', 'ist']
# RT @clemens_carlo: Linke, Grüne und Progressive veröden unsere Städte. Schönheit und Identität sind für sie nichts weiter als rückwärtsgewa…
# ['Linke', 'Grne', 'und', 'Progressive', 'verden', 'unsere', 'Stdte', 'Schnheit', 'und', 'Identitt', 'sind', 'fr', 'sie', 'nichts', 'weiter', 'als', 'rckwrtsgewa']
# RT @AlternativeNRW: ++ Impfkampagne: Bundesregierung gibt #Schauspieler als normale Bürger aus ++
# Bei mind. 2 Personen handelt es sich offe…
# ['Impfkampagne', 'Bundesregierung', 'gibt', 'als', 'normale', 'Brger', 'aus', 'Bei', 'mind', 'Personen', 'handelt', 'es', 'sich', 'offe']
# RT @Dennis_Hohloch: Die Mitglieder des Landtages #Brandenburg haben mich heute in das wichtige #Kontrollgremium des öffentlich-rechtlichen…
# ['Die', 'Mitglieder', 'des', 'Landtages', 'haben', 'mich', 'heute', 'in', 'das', 'wichtige', 'des', 'ffentlich-rechtlichen']
# Viele Bürger sind trotz #Arbeit von #Armut betroffen.
#
# Armut bekämpft man nicht mit #Entlastungspaketen, sondern indem Lebenskosten gesenkt, #Investitionen ermöglicht und #Steuern nicht in alle Herren Länder oder für unsinnige Projekte verschleudert werden. #UnserLandzuerst #AfD https://t.co/34vOg3qkTf
# ['Brger', 'sind', 'trotz', 'von', 'betroffen', 'Armut', 'bekmpft', 'man', 'nicht', 'mit', 'sondern', 'indem', 'Lebenskosten', 'gesenkt', 'ermglicht', 'und', 'nicht', 'in', 'alle', 'Herren', 'Lnder', 'oder', 'fr', 'unsinnige', 'Projekte', 'verschleudert', 'werden']
# Es ist ein überfälliger Schritt, dass sich nun auch #Verkehrsbetriebe für das Ende der sinnlosen #Maskenpflicht im #ÖPNV aussprechen. Mit dem von #Hysterie geprägten #Lauterbach-Sonderweg unseres Landes muss endlich Schluss sein! #Corona #Masken #AfD
#
# https://t.co/tCDnTg8wVE
# ['ist', 'ein', 'berflliger', 'Schritt', 'dass', 'sich', 'nun', 'auch', 'fr', 'das', 'Ende', 'der', 'sinnlosen', 'im', 'aussprechen', 'Mit', 'dem', 'von', 'geprgten', '-Sonderweg', 'unseres', 'Landes', 'muss', 'endlich', 'Schluss', 'sein']
# Wer sich heute anhören will, wie die #Ampel die Energieversorgung eines ganzen Landes an die Wand fährt, hat ab 11 Uhr im Parlamentsfernsehen des Bundestages die Gelegenheit dazu. Ungefilterte Verblendung und Ideologie von #Grünen, #FDP und #SPD live auf https://t.co/MLPTqDvLhh https://t.co/kZZzpWFHgm
# ['sich', 'heute', 'anhren', 'will', 'wie', 'die', 'die', 'Energieversorgung', 'eines', 'ganzen', 'Landes', 'an', 'die', 'Wand', 'fhrt', 'hat', 'ab', 'Uhr', 'im', 'Parlamentsfernsehen', 'des', 'Bundestages', 'die', 'Gelegenheit', 'dazu', 'Ungefilterte', 'Verblendung', 'und', 'Ideologie', 'von', 'und', 'live', 'auf']
# RT @AlternativeNRW: ++ 𝐕𝐞𝐫𝐝𝐨𝐩𝐩𝐞𝐥𝐭: Jeder 8. Wähler in #NRW wählt #AfD! ++ https://t.co/One18yNTBw
# ['Jeder', 'Whler', 'in', 'whlt']
# RT @Rene_Springer: Abschiebeflüge mit #AfD-Regierung. (Symbolbild) https://t.co/AuQEiMnO6w
# ['Abschiebeflge', 'mit', '-Regierung', 'Symbolbild']
# RT @blackoutmelder: Tausende Kunden der Düsseldorfer #Stadtwerke müssen sich zum neuen Jahr einen neuen Energieversorger suchen. Die Stadtw…
# ['Tausende', 'Kunden', 'der', 'Dsseldorfer', 'mssen', 'sich', 'zum', 'neuen', 'Jahr', 'einen', 'neuen', 'Energieversorger', 'suchen', 'Die', 'Stadtw']
# RT @blackoutmelder: Dieser Vorfall war zwar kein #Blackout, aber er zeigt uns, welche lebensgefährlichen Auswirkungen er hätte. Nachdem ein…
# ['Dieser', 'Vorfall', 'war', 'zwar', 'kein', 'aber', 'er', 'zeigt', 'uns', 'welche', 'lebensgefhrlichen', 'Auswirkungen', 'er', 'htte', 'Nachdem', 'ein']
# RT @blackoutmelder: Schlecht vorbereitet auf einen möglichen #Blackout ist offenbar die Millionenstadt #Hamburg: Die dortigen 87 #Notbrunne…
# ['Schlecht', 'vorbereitet', 'auf', 'einen', 'mglichen', 'ist', 'offenbar', 'die', 'Millionenstadt', 'Die', 'dortigen']
# Ohne Ankündigung hat uns #Twitter am gestrigen Abend den Zugang zu unserem Profil gesperrt. Wir freuen uns, dass unserem Einspruch entsprochen und die Sperre aufgehoben wurde. #AfD
#
# https://t.co/C1IahuYbuI
# ['Ankndigung', 'hat', 'uns', 'am', 'gestrigen', 'Abend', 'den', 'Zugang', 'zu', 'unserem', 'Profil', 'gesperrt', 'Wir', 'freuen', 'uns', 'dass', 'unserem', 'Einspruch', 'entsprochen', 'und', 'die', 'Sperre', 'aufgehoben', 'wurde']
# RT @blackoutmelder: In einer Broschüre fordert die Stadt Bad Honnef (#NRW) dazu auf, sich für den Fall eines längeren Stromausfalls vorzube…
# ['In', 'einer', 'Broschre', 'fordert', 'die', 'Stadt', 'Bad', 'Honnef', 'dazu', 'auf', 'sich', 'fr', 'den', 'Fall', 'eines', 'lngeren', 'Stromausfalls', 'vorzube']
# RT @blackoutmelder: Das #THW im bayerischen #Erlangen hat einen möglichen #Blackout geprobt. Die Maßnahme erfolgt aus gutem Grund, denn ohn…
# ['Das', 'im', 'bayerischen', 'hat', 'einen', 'mglichen', 'geprobt', 'Die', 'Manahme', 'erfolgt', 'aus', 'gutem', 'Grund', 'denn', 'ohn']
# Herbe Schlappe für die #Ampel zum #Wochenstart: Der #Bundesrat hat das #Bürgergeld gestoppt. Also erst einmal kein Rundum-Sorglos-Paket, von dem größtenteils #Zuwanderer profitieren würden. Illegale #Migration muss eingedämmt und nicht vergoldet werden!
#
# https://t.co/rl2smmCHGW
# ['Schlappe', 'fr', 'die', 'zum', 'Der', 'hat', 'das', 'gestoppt', 'Also', 'erst', 'einmal', 'kein', 'Rundum-Sorglos-Paket', 'von', 'dem', 'grtenteils', 'profitieren', 'wrden', 'Illegale', 'muss', 'eingedmmt', 'und', 'nicht', 'vergoldet', 'werden']
# Unser #Sozialstaat darf kein #Asyl-Grund sein! Ob aus #Ukraine oder #Maghreb: Sach- statt Geldleistungen!
#
# https://t.co/FYdkLcg3sv
# #Zuwanderer #Bürgergeld #AnneWill #Scholz #Ampel #AfD #UnserLandzuerst https://t.co/bBJ65LfVWM
# ['darf', 'kein', '-Grund', 'sein', 'Ob', 'aus', 'oder', 'Sach-', 'statt', 'Geldleistungen']
# RT @AfDimEUParl: ➡️ Zeitumstellung: So kläglich scheitert die EU!
# 2018 sprachen sich bei einer Umfrage 84 % der 4,6 Mio. Befragten für ein…
# ['Zeitumstellung', 'So', 'klglich', 'scheitert', 'die', 'EU', 'sprachen', 'sich', 'bei', 'einer', 'Umfrage', 'der', 'Mio', 'Befragten', 'fr', 'ein']
# RT @StBrandner: #Klima-#RAF/ #GrüneArmeeFraktion/ #GAF Einhalt gebieten! Kein #Oppositionspopulismus der #cdu!
# #Anwendung bestehender Vorsc…
# ['-', 'Einhalt', 'gebieten', 'Kein', 'der', 'bestehender', 'Vorsc']
# RT @M_Reichardt_AfD: Wie überall in Sachsen-Anhalt, so haben auch wir in der Börde heute an den lokalen Ehrenmälern unserer Gefallenen geda…
# ['Wie', 'berall', 'in', 'Sachsen-Anhalt', 'so', 'haben', 'auch', 'wir', 'in', 'der', 'Brde', 'heute', 'an', 'den', 'lokalen', 'Ehrenmlern', 'unserer', 'Gefallenen', 'geda']
# RT @M_Reichardt_AfD: Sogar der 🇩🇪Mainstream nimmt sich des Themas an! Die kriminellen sog. "#Klimaaktivisten werden für menschenverachtende…
# ['Sogar', 'der', 'Mainstream', 'nimmt', 'sich', 'des', 'Themas', 'an', 'Die', 'kriminellen', 'sog', 'werden', 'fr', 'menschenverachtende']
# #heißerHerbst geht weiter: Beispielsweise am kommenden Samstag, 19.11. um 12 Uhr auf dem Domplatz in #Speyer. Wir freuen uns auf Ihren Besuch! Mit: @Tino_Chrupalla, @Jan_Bollinger @S_Muenzenmaier @Nicole_Hoechst und @Schattner_MdB
# #AfD #UnserLandzuerst https://t.co/o7Cyk6dXGL
# ['weiter', 'Beispielsweise', 'am', 'kommenden', 'Samstag', 'um', 'Uhr', 'auf', 'dem', 'Domplatz', 'in', 'Wir', 'freuen', 'uns', 'auf', 'Ihren', 'Besuch', 'Mit', 'TinoChrupalla', 'JanBollinger', 'SMuenzenmaier', 'NicoleHoechst', 'und', 'SchattnerMdB']
# 🎧🔥 Ausgabe 42/22 unseres #Podcast s - jetzt reinhören! 7 Tage #Deutschland – der #AfD-Wochenendpodcast mit vielen spannenden Themen!
#
# ▶ https://t.co/xX7koQ23Vx
# ▶ https://t.co/jGYf1ORasA
# ▶ https://t.co/cC1WqE8YJ1
#
# #Bürgergeld #Zuwanderer #Migration #Chrupalla #GEZ #RBB https://t.co/OPINNeQUi8
# ['unseres', 's', '-', 'jetzt', 'reinhren', 'Tage', 'der', '-Wochenendpodcast', 'mit', 'vielen', 'spannenden', 'Themen']
# Ein #Gesundheitsminister, der die Gesellschaft gespalten und die #Wirtschaft geschädigt hat, der mit Prognosen ständig falsch lag und im #Filz-Sumpf versinkt, hat komplett versagt. Er sollte zurücktreten.
# #LauterbachRuecktrittJetzt #AfD #UnserLandzuerst
#
# https://t.co/QaxuxkhFtx
# ['der', 'die', 'Gesellschaft', 'gespalten', 'und', 'die', 'geschdigt', 'hat', 'der', 'mit', 'Prognosen', 'stndig', 'falsch', 'lag', 'und', 'im', '-Sumpf', 'versinkt', 'hat', 'komplett', 'versagt', 'Er', 'sollte', 'zurcktreten']
# Ein „Mann“ ruft bereits im Februar in der U-Bahn „Allahu Akbar“ und „Ich werde alle Deutschen töten“. Jetzt fahndet die #Polizei mit Fotos...
# #AfD #UnserLandzuerst
#
# https://t.co/LPsTYPrX8E https://t.co/qGKrL34Ipx
# ['Mann', 'ruft', 'bereits', 'im', 'Februar', 'in', 'der', 'U-Bahn', 'Allahu', 'Akbar', 'und', 'Ich', 'werde', 'alle', 'Deutschen', 'tten', 'Jetzt', 'fahndet', 'die', 'mit', 'F']
# RT @M_Reichardt_AfD: Auch hier hatten wir als @AfD immer gewarnt. Die #Impfnebenwirkungen wurden besonders von #Lauterbach und dem @BMG_Bun…
# ['Auch', 'hier', 'hatten', 'wir', 'als', 'AfD', 'immer', 'gewarnt', 'Die', 'wurden', 'besonders', 'von', 'und', 'dem', 'BMGBun']
# RT @Dennis_Hohloch: Haltet ihr es für gerechtfertigt, monatlich 18,36 Euro für den #Rundfunk zu bezahlen? Plädiert ihr für eine gänzliche A…
# ['Haltet', 'ihr', 'es', 'fr', 'gerechtfertigt', 'monatlich', 'Euro', 'fr', 'den', 'zu', 'bezahlen', 'Pldiert', 'ihr', 'fr', 'eine', 'gnzliche', 'A']
# Endlich eine echte #Fachkraft: #TerenceHill ist deutscher Staatsbürger! Wir hoffen, dass er diesen Schritt angesichts der fatalen Regierungspolitik der #Ampel nicht schnell wieder bereut. https://t.co/30ZzjKoNCB
# ['eine', 'echte', 'ist', 'deutscher', 'Staatsbrger', 'Wir', 'hoffen', 'dass', 'er', 'diesen', 'Schritt', 'angesichts', 'der', 'fatalen', 'Regierungspolitik', 'der', 'nicht', 'schnell', 'wieder', 'bereut']
# RT @KrahMax: Die deutsche und EU-Klimapolitik in 1:15 min widerlegt: Anschauen! Wir ruinieren uns ohne einen einzigen positiven Effekt.
# ['Die', 'deutsche', 'und', 'EU-Klimapolitik', 'in', 'min', 'widerlegt', 'Anschauen', 'Wir', 'ruinieren', 'uns', 'ohne', 'einen', 'einzigen', 'positiven', 'Effekt']
# RT @Dennis_Hohloch: Nach 750 Sendungen #HartaberFair und seiner ihm wohl zustehenden Megapension beklagt Frank #Plasberg die Einseitigkeit…
# ['Nach', 'Sendungen', 'und', 'seiner', 'ihm', 'wohl', 'zustehenden', 'Megapension', 'beklagt', 'Frank', 'die', 'Einseitigkeit']
# RT @Alice_Weidel: Sorgten #SPD &amp; #CDU schon 2021 für 63 % mehr illegale Einwanderung, wird diese Zahl in diesem Jahr voraussichtlich deutli…
# ['Sorgten', 'amp', 'schon', 'fr', 'mehr', 'illegale', 'Einwanderung', 'wird', 'diese', 'Zahl', 'in', 'diesem', 'Jahr', 'voraussichtlich', 'deutli']
# Erfolg für die #AfD: Der #Landtag in #Thüringen muss in seiner öffentlichen Kommunikation auf #Gender-Stammelsprache verzichten. Gut so, denn das Gendern ist eine Respektlosigkeit gegenüber der deutschen Sprache und Kultur. #UnserLandzuerst
#
# https://t.co/CftsZIMW0W
# ['fr', 'die', 'Der', 'in', 'muss', 'in', 'seiner', 'ffentlichen', 'Kommunikation', 'auf', '-Stammelsprache', 'verzichten', 'Gut', 'so', 'denn', 'das', 'Gendern', 'ist', 'eine', 'Respektlosigkeit', 'gegenber', 'der', 'deutschen', 'Sprache', 'und', 'Kultur']
# RT @blackoutmelder: In #Kiel sollte mit einer Übung erprobt werden, ob die städtische #Feuerwehr einen dreitägigen #Stromausfall verkraften…
# ['In', 'sollte', 'mit', 'einer', 'bung', 'erprobt', 'werden', 'ob', 'die', 'stdtische', 'einen', 'dreitgigen', 'verkraften']
# Die #CDU/#CSU-Fraktion im #Bundestag bleibt sich ideologisch treu: Die Wegbereiter der #Grünen, die die #Energiewende und den Kernkraftausstieg erst auf den Weg brachten, agieren auch weiterhin an den echten Problemen der Bürger vorbei. Deshalb #AfD! #UnserLandZuerst https://t.co/rUW6ZR9o9O
# ['-Fraktion', 'im', 'bleibt', 'sich', 'ideologisch', 'treu', 'Die', 'Wegbereiter', 'der', 'die', 'die', 'und', 'den', 'Kernkraftausstieg', 'erst', 'auf', 'den', 'Weg', 'brachten', 'agieren', 'auch', 'weiterhin', 'an', 'den', 'echten', 'Problemen', 'der', 'Brger', 'vorbei', 'Deshalb']
# RT @blackoutmelder: Die #Stadtwerke in #Herrenberg (Kreis #Böblingen, Baden-Württemberg) lassen alle aktuellen #Stromverträge auslaufen. La…
# ['Die', 'in', 'Kreis', 'Baden-Wrttemberg', 'lassen', 'alle', 'aktuellen', 'auslaufen', 'La']
# RT @Alice_Weidel: #Pfizer selbst sagt, dass der eigene #Impfstoff nie darauf getestet wurde, ob er vor Ansteckung schütze. Die Faktenverdre…
# ['selbst', 'sagt', 'dass', 'der', 'eigene', 'nie', 'darauf', 'getestet', 'wurde', 'ob', 'er', 'vor', 'Ansteckung', 'schtze', 'Die', 'Faktenverdre']
# RT @blackoutmelder: Bei einem #Gas-Jahresverbrauch von 18.000 kWh errechnet #Hamburg Energie für 2023 eine #Jahresrechnung von rund 3489 Eu…
# ['Bei', 'einem', '-Jahresverbrauch', 'von', 'kWh', 'errechnet', 'Energie', 'fr', 'eine', 'von', 'rund', 'Eu']
# RT @M_Reichardt_AfD: War zu erwarten: Dekadente Bonzen finanzieren #Klimaterroristen!
# "Demnach finanzieren sie Plakate, Flyer, Banner und d…
# ['War', 'zu', 'erwarten', 'Dekadente', 'Bonzen', 'finanzieren', 'Demnach', 'finanzieren', 'sie', 'Plakate', 'Flyer', 'Banner', 'und', 'd']
# RT @Dennis_Hohloch: #Klimakleber sind Extremisten. Da gibt es keine Diskussion. #LetztenGeneration https://t.co/SXWcOlfyYM
# ['sind', 'Extremisten', 'Da', 'gibt', 'es', 'keine', 'Diskussion']
# RT @AfDimEUParl: ➡️HUCH: Auflösungserscheinungen bei @Gruene_Europa / @Die_Gruenen?
# Sowohl für die Menschen in der EU als auch in 🇩🇪 Deuts…
# ['HUCH', 'Auflsungserscheinungen', 'bei', 'GrueneEuropa', 'DieGruenen', 'Sowohl', 'fr', 'die', 'Menschen', 'in', 'der', 'EU', 'als', 'auch', 'in', 'Deuts']
# Nur die #AfD stellt sich gegen den Ausverkauf deutscher Interessen! #UnserLandzuerst
#
# Neue Abhängigkeiten drohen, unser Land wird weiter ausverkauft - und die #FDP hält brav den #Steigbügel.
#
# https://t.co/sFXuGWYUWB #SPD #Lambrecht #Lindner https://t.co/IHFhBaZ4ok
# ['die', 'stellt', 'sich', 'gegen', 'den', 'Ausverkauf', 'deutscher', 'Interessen', 'Neue', 'Abhngigkeiten', 'drohen', 'unser', 'Land', 'wird', 'weiter', 'ausverkauft', '-', 'und', 'die', 'hlt', 'brav', 'den']
# Werden offizielle Zahlen bewusst klein gehalten? Eine Umfrage ergab, dass fast ein Viertel der Geimpften über erhebliche #Impf-Nebenwirkungen klagt. Währenddessen wird #Panik vor der nächsten Variante geschürt. #Lauterbach und #Pfizer wird es freuen. #AfD
#
# https://t.co/McudizeWDr
# ['offizielle', 'Zahlen', 'bewusst', 'klein', 'gehalten', 'Eine', 'Umfrage', 'ergab', 'dass', 'fast', 'ein', 'Viertel', 'der', 'Geimpften', 'ber', 'erhebliche', '-Nebenwirkungen', 'klagt', 'Whrenddessen', 'wird', 'vor', 'der', 'nchsten', 'Variante', 'geschrt', 'und', 'wird', 'es', 'freuen']
# Für die #Ampel gilt augenscheinlich "America first". Nicht nur beim Thema Rüstungsindustrie, sondern auch auf nahezu alle anderen Industrien bezogen, die durch die Energiepolitik der #Bundesregierung vor allem in die #USA getrieben werden. https://t.co/1vIzojx2fd
# ['die', 'gilt', 'augenscheinlich', 'America', 'first', 'Nicht', 'nur', 'beim', 'Thema', 'Rstungsindustrie', 'sondern', 'auch', 'auf', 'nahezu', 'alle', 'anderen', 'Industrien', 'bezogen', 'die', 'durch', 'die', 'Energiepolitik', 'der', 'vor', 'allem', 'in', 'die', 'getrieben', 'werden']
# RT @blackoutmelder: In einem #Kinderkrankenhaus in #Hannover ist es am Montag zu einem #Stromausfall gekommen. Einige Bereiche des Krankenh…
# ['In', 'einem', 'in', 'ist', 'es', 'am', 'Montag', 'zu', 'einem', 'gekommen', 'Einige', 'Bereiche', 'des', 'Krankenh']
# RT @M_Reichardt_AfD: Sehr gute Veranstaltung der Desiderius Erasmus Stiftung Schleswig-Holstein. Gemeinsam mit @KrahMax Sebastian Maack, Ch…
# ['Sehr', 'gute', 'Veranstaltung', 'der', 'Desiderius', 'Erasmus', 'Stiftung', 'Schleswig-Holstein', 'Gemeinsam', 'mit', 'KrahMax', 'Sebastian', 'Maack', 'Ch']
# RT @blackoutmelder: Tausende Haushalte in #Mannheim (Baden-Württemberg) waren am vergangenen Freitagvormittag stundenlang ohne Strom. #blac…
# ['Tausende', 'Haushalte', 'in', 'Baden-Wrttemberg', 'waren', 'am', 'vergangenen', 'Freitagvormittag', 'stundenlang', 'ohne', 'Strom']
# Autobahn-#Kleber endlich bekämpfen!
#
# Es ist untragbar, dass die #Klima-Extremisten mit albernen Strafen davonkommen. Wer Leben gefährdet, um seine #grüne Ideologie durchzusetzen, gehört ins Gefängnis und nicht ins Fernsehstudio!
#
# https://t.co/Ekxex1lt6P #LetzteGeneration #AfD https://t.co/tj4MtTanmP
# ['endlich', 'bekmpfenEs', 'ist', 'untragbar', 'dass', 'die', '-Extremisten', 'mit', 'albernen', 'Strafen', 'davonkommen', 'Wer', 'Leben', 'gefhrdet', 'um', 'seine', 'Ideologie', 'durchzusetzen', 'gehrt', 'ins', 'Gefngnis', 'und', 'nicht', 'ins', 'Fernsehstudio']
# RT @Tino_Chrupalla: SPD-Fraktionschef Rolf #Mützenich steht auf einer Liste der Ukraine, weil er dem Land zum Waffenstillstand riet. Egal o…
# ['SPD-Fraktionschef', 'Rolf', 'steht', 'auf', 'einer', 'Liste', 'der', 'Ukraine', 'weil', 'er', 'dem', 'Land', 'zum', 'Waffenstillstand', 'riet', 'Egal', 'o']
# RT @Alice_Weidel: Der #FDP-Vorschlag zur Einführung eines digitalen #Euro ist nichts anderes als eine #Bargeld-Abschaffung und damit die Ei…
# ['Der', '-Vorschlag', 'zur', 'Einfhrung', 'eines', 'digitalen', 'ist', 'nichts', 'anderes', 'als', 'eine', '-Abschaffung', 'und', 'damit', 'die', 'Ei']
# RT @Dennis_Hohloch: Der #Ausländer|anteil in #HartzIV hat sich seit 2016 von 25% auf 45% fast verdoppelt!
# Es wird höchste Zeit, die illegal…
# ['Der', 'anteil', 'in', 'hat', 'sich', 'seit', 'von', 'auf', 'fast', 'verdoppeltEs', 'wird', 'hchste', 'Zeit', 'die', 'illegal']
# RT @PeterBoehringer: Am 9. November, dem deutschen Schicksalstag:
# Es wird einen Demozug geben, der an mehreren Münchener Gerichten vorbeifü…
# ['Am', 'November', 'dem', 'deutschen', 'SchicksalstagEs', 'wird', 'einen', 'Demozug', 'geben', 'der', 'an', 'mehreren', 'Mnchener', 'Gerichten', 'vorbeif']
# RT @clemens_carlo: https://t.co/6W6RKwTEHY
# []
# RT @Dennis_Hohloch: Warum brauchen wir einen Untersuchungsausschuss #rbb? https://t.co/nk4Zkdey7g
# ['Warum', 'brauchen', 'wir', 'einen', 'Untersuchungsausschuss']
# RT @M_Reichardt_AfD: Wer den Strassenterror dieser #Klimaterroristen für seine Regierungsarbeit benötigt, der wird natürlich das Strafrecht…
# ['Wer', 'den', 'Strassenterror', 'dieser', 'fr', 'seine', 'Regierungsarbeit', 'bentigt', 'der', 'wird', 'natrlich', 'das', 'Strafrecht']
# RT @blackoutmelder: Wenn es in #berlin zu einem #blackout kommt, haben die Einwohner nur für anderthalb Tage Trinkwasser! Man solle sich Vo…
# ['Wenn', 'es', 'in', 'zu', 'einem', 'kommt', 'haben', 'die', 'Einwohner', 'nur', 'fr', 'anderthalb', 'Tage', 'Trinkwasser', 'Man', 'solle', 'sich', 'Vo']
# RT @blackoutmelder: Kunden des Stromversorgers #Envia müssen ab dem 1. Januar 2023 fast doppelt so viel für ihren #Strom zahlen.Als Gründe…
# ['Kunden', 'des', 'Stromversorgers', 'mssen', 'ab', 'dem', 'Januar', 'fast', 'doppelt', 'so', 'viel', 'fr', 'ihren', 'zahlenAls', 'Grnde']
# RT @blackoutmelder: Laut einer #Umfrage des #Civey-Instituts rechnen 42 % der Deutschen bereits in diesem #Winter mit zeitlich begrenzten #…
# ['Laut', 'einer', 'des', '-Instituts', 'rechnen', 'der', 'Deutschen', 'bereits', 'in', 'diesem', 'mit', 'zeitlich', 'begrenzten']
# #Asyl-Anträge auf dem höchsten Stand seit 2016!
#
# Wenn die #Ampel nicht endlich umlenkt und die überzogene #Hypermoral beiseitelegt, steuert #Deutschland auf eine soziale &amp; wirtschaftliche #Katastrophe zu.
#
# https://t.co/PXVUuMcAmL #AfD #Migration #Zuwanderer #UnserLandzuerst https://t.co/XVIjWZWjb7
# ['auf', 'dem', 'hchsten', 'Stand', 'seit', 'Wenn', 'die', 'nicht', 'endlich', 'umlenkt', 'und', 'die', 'berzogene', 'beiseitelegt', 'steuert', 'auf', 'eine', 'soziale', 'amp', 'wirtschaftliche', 'zu']
# RT @AfDimBundestag: LIVE: Pressekonferenz der #AfD-Fraktion! @BerndBaumannAfD, Parl. Geschäftsführer der Fraktion, stellt mit weiteren Abge…
# ['LIVE', 'Pressekonferenz', 'der', '-Fraktion', 'BerndBaumannAfD', 'Parl', 'Geschftsfhrer', 'der', 'Fraktion', 'stellt', 'mit', 'weiteren', 'Abge']
# RT @M_HarderKuehnel: Seit 2016 stieg der Anteil von #Migranten in Hartz IV von 25 auf 45%. Die Dunkelziffer dürfte deutlich höher sein, da…
# ['Seit', 'stieg', 'der', 'Anteil', 'von', 'in', 'Hartz', 'IV', 'von', 'auf', 'Die', 'Dunkelziffer', 'drfte', 'deutlich', 'hher', 'sein', 'da']
# RT @Dennis_Hohloch: Dieselben Parteien, die vor einem Jahr noch sämtliche unangemeldete #Spaziergänge kriminalisiert haben, bezeichnen heut…
# ['Dieselben', 'Parteien', 'die', 'vor', 'einem', 'Jahr', 'noch', 'smtliche', 'unangemeldete', 'kriminalisiert', 'haben', 'bezeichnen', 'heut']
# RT @Dennis_Hohloch: In der Chemnitzer Innenstadt soll ein „#arabisch aussehender Mann“ eine 20-Jährige vergewaltigt haben. Dank der Politik…
# ['In', 'der', 'Chemnitzer', 'Innenstadt', 'soll', 'ein', 'aussehender', 'Mann', 'eine', '-Jhrige', 'vergewaltigt', 'haben', 'Dank', 'der', 'Politik']
# RT @M_HarderKuehnel: Nun bejubelt @c_lindner auch noch den digitalen Euro. Dieser würde bedeuten: Mehr Totalüberwachung. Negativzinsen. Kei…
# ['Nun', 'bejubelt', 'clindner', 'auch', 'noch', 'den', 'digitalen', 'Euro', 'Dieser', 'wrde', 'bedeuten', 'Mehr', 'Totalberwachung', 'Negativzinsen', 'Kei']
# RT @Dennis_Hohloch: Spitzenfunktionäre im ÖR-#Rundfunk verdienen nach Ende ihres Arbeitsverhältnisses munter weiter!
# So bekommt man nach nu…
# ['Spitzenfunktionre', 'im', 'R-', 'verdienen', 'nach', 'Ende', 'ihres', 'Arbeitsverhltnisses', 'munter', 'weiterSo', 'bekommt', 'man', 'nach', 'nu']
# RT @blackoutmelder: Mecklenburg-Vorpommerns #Innenminister ruft die Bürger dazu auf, sich mit einem #Notvorrat gegen mögliche Ausfälle bei…
# ['Mecklenburg-Vorpommerns', 'ruft', 'die', 'Brger', 'dazu', 'auf', 'sich', 'mit', 'einem', 'gegen', 'mgliche', 'Ausflle', 'bei']
# RT @blackoutmelder: 53 % der Befragten halten Robert #Habeck nicht für geeignet für das Amt des #Wirtschaftsministers. Das ist freilich kei…
# ['der', 'Befragten', 'halten', 'Robert', 'nicht', 'fr', 'geeignet', 'fr', 'das', 'Amt', 'des', 'Das', 'ist', 'freilich', 'kei']
# RT @blackoutmelder: Die #Bundesnetzagentur versucht offenbar zunehmend, den Begriff #Blackout zu vermeiden und stattdessen von #Brownout zu…
# ['Die', 'versucht', 'offenbar', 'zunehmend', 'den', 'Begriff', 'zu', 'vermeiden', 'und', 'stattdessen', 'von', 'zu']
# RT @Alice_Weidel: Städte und Gemeinden wollen die Einführung des Bürgergeldes verschieben, während dessen Sogwirkung bereits einsetzt und s…
# ['Stdte', 'und', 'Gemeinden', 'wollen', 'die', 'Einfhrung', 'des', 'Brgergeldes', 'verschieben', 'whrend', 'dessen', 'Sogwirkung', 'bereits', 'einsetzt', 'und', 's']
# #AfD im #Bundestag fordert #Verhandlungen: Nur #Diplomatie kann diesen #Krieg beenden!
# Schluss mit dem #Säbelrasseln, Schluss mit den #Sanktionen und Schluss mit der latenten Gefahr eines #Atomkrieges!
# https://t.co/OpANBrxCOE #UnserLandzuerst https://t.co/Ii1PRJKsqu
# ['fordert', 'Nur', 'kann', 'diesen', 'beendenSchluss', 'mit', 'dem', 'Schluss', 'mit', 'den', 'und', 'Schluss', 'mit', 'der', 'latenten', 'Gefahr', 'eines']
# RT @blackoutmelder: Ein Versorger in #Coburg hat die #Strompreise um 80 % erhöht. Auch bei anderen Versorgern ist aufgrund der #Energiepoli…
# ['Ein', 'Versorger', 'in', 'hat', 'die', 'um', 'erhht', 'Auch', 'bei', 'anderen', 'Versorgern', 'ist', 'aufgrund', 'der']
# 🎧🔥 Ausgabe 41/22 unseres #Podcast s - jetzt reinhören! 7 Tage #Deutschland – der #AfD-Wochenendpodcast mit vielen spannenden Themen!
#
# ▶ https://t.co/xX7koPJUHp
# ▶ https://t.co/24qQop222W
# ▶ https://t.co/cC1WqEq1L1
#
# #Asyl #Zuwanderer #Faeser #Baum #Hess #SPD #Lauterbach https://t.co/RBVv3S6GoY
# ['unseres', 's', '-', 'jetzt', 'reinhren', 'Tage', 'der', '-Wochenendpodcast', 'mit', 'vielen', 'spannenden', 'Themen']
# RT @Dennis_Hohloch: 40-50 Mio. Euro zahlen wir pro Jahr allein für die Gehälter der #GEZ-Mitarbeiter, die unsere Zwangsbeiträge für den teu…
# ['-', 'Mio', 'Euro', 'zahlen', 'wir', 'pro', 'Jahr', 'allein', 'fr', 'die', 'Gehlter', 'der', '-Mitarbeiter', 'die', 'unsere', 'Zwangsbeitrge', 'fr', 'den', 'teu']
# RT @AfDimBundestag: „Corona-Kita-Studie“ zeigt: Kitas waren keine Infektionsherde und die Schließungen während der #Pandemie unnötig! "Die…
# ['Corona-Kita-Studie', 'zeigt', 'Kitas', 'waren', 'keine', 'Infektionsherde', 'und', 'die', 'Schlieungen', 'whrend', 'der', 'unntig', 'Die']
# Nach 482 Jahren: #Baerbock lässt #Kreuz aus Rathaus entfernen.
#
# Nur die #AfD stellt sich dieser #Unterwerfung entgegen und steht zu unserer #Kultur und #Identität!
#
# https://t.co/gmNdT7cw0J #UnserLandzuerst https://t.co/Xq7YwgSXAu
# ['Jahren', 'lsst', 'aus', 'Rathaus', 'entfernenNur', 'die', 'stellt', 'sich', 'dieser', 'entgegen', 'und', 'steht', 'zu', 'unserer', 'und']
# RT @Tino_Chrupalla: Der @Bundeskanzler zeigt in China mehr Realitätssinn als seine grünen Minister mit ihrer „wertegeleiteten Außenpolitik“…
# ['Der', 'Bundeskanzler', 'zeigt', 'in', 'China', 'mehr', 'Realittssinn', 'als', 'seine', 'grnen', 'Minister', 'mit', 'ihrer', 'wertegeleiteten', 'Auenpolitik']
# #Grenzen sichern – #Anreize beenden – #Migrationskrise bewältigen!
#
# #Faeser rechnet sich die alarmierenden Zahlen der nach #Deutschland strömenden #Zuwanderer schön. So gibt ihr Ministerium viel geringere Zahlen an, als tatsächlich gezählt werden.
#
# https://t.co/bpZLdrXSTN #AfD https://t.co/7tG9dLCbCd
# ['beenden', 'bewltigen', 'rechnet', 'sich', 'die', 'alarmierenden', 'Zahlen', 'der', 'nach', 'strmenden', 'schn', 'So', 'gibt', 'ihr', 'Ministerium', 'viel', 'geringere', 'Zahlen', 'an', 'als', 'tatschlich', 'gezhlt', 'werden']
# RT @clemens_carlo: Sagen wir, wie es ist:
#
# Die Frau, die von einem Betonmischer erfasst wurde, könnte mutmaßlich noch am Leben sein, wenn…
# ['Sagen', 'wir', 'wie', 'es', 'ist', 'Die', 'Frau', 'die', 'von', 'einem', 'Betonmischer', 'erfasst', 'wurde', 'knnte', 'mutmalich', 'noch', 'am', 'Leben', 'sein', 'wenn']
# RT @clemens_carlo: 🇩🇪 Junge Alternative: Steht für Heimat &amp; Kultur, protestiert gegen die sinnlose Abholzung von Wäldern für #Windkraft.…
# ['Junge', 'Alternative', 'Steht', 'fr', 'Heimat', 'amp', 'Kultur', 'protestiert', 'gegen', 'die', 'sinnlose', 'Abholzung', 'von', 'Wldern', 'fr']
# RT @AfDimEUParl: ➡️ Die EU benimmt sich wie ein Kolonialherr!
# Autonomie und Unabhängigkeit sind zu respektieren:
# @KrahMax mahnt bei der Di…
# ['Die', 'EU', 'benimmt', 'sich', 'wie', 'ein', 'Kolonialherr', 'Autonomie', 'und', 'Unabhngigkeit', 'sind', 'zu', 'respektierenKrahMax', 'mahnt', 'bei', 'der', 'Di']
# RT @Dennis_Hohloch: Das #Ölembargo vernichtet tausende Arbeitsplätze, gefährdet unsere Energiesicherheit und verteuert den #Sprit.
# Allein i…
# ['Das', 'vernichtet', 'tausende', 'Arbeitspltze', 'gefhrdet', 'unsere', 'Energiesicherheit', 'und', 'verteuert', 'den', 'Allein', 'i']
# Unsere Gedanken sind bei den Angehörigen der Verstorbenen.
#
# Mehr erfahren:
# https://t.co/k4NSchMZh3 #Klimakleber #Berlin #LetzteGeneration #Rettungsgasse #AfD https://t.co/hqWpEr2KyQ
# ['Gedanken', 'sind', 'bei', 'den', 'Angehrigen', 'der', 'Verstorbenen', 'Mehr', 'erfahren']
# RT @KrahMax: Warum immer derselbe Täterhintergrund? Die ganze Einwanderei ist gescheitert, sie hat Probleme geschaffen, für die es bislang…
# ['Warum', 'immer', 'derselbe', 'Tterhintergrund', 'Die', 'ganze', 'Einwanderei', 'ist', 'gescheitert', 'sie', 'hat', 'Probleme', 'geschaffen', 'fr', 'die', 'es', 'bislang']
# RT @Tino_Chrupalla: Wir stehen vor einer massiven Krise. Und die Regierungschefs schachern um Steuergeld. Weder Preisbremsen noch Bürgergel…
# ['Wir', 'stehen', 'vor', 'einer', 'massiven', 'Krise', 'Und', 'die', 'Regierungschefs', 'schachern', 'um', 'Steuergeld', 'Weder', 'Preisbremsen', 'noch', 'Brgergel']
# RT @Alice_Weidel: Mehr als 30 Jahre Geschäftsbetrieb, 89 Mitarbeiter sehen sich einer ungewissen Zukunft entgegen: Chiemgauer Naturfleisch…
# ['Mehr', 'als', 'Jahre', 'Geschftsbetrieb', 'Mitarbeiter', 'sehen', 'sich', 'einer', 'ungewissen', 'Zukunft', 'entgegen', 'Chiemgauer', 'Naturfleisch']
# RT @blackoutmelder: AfD-Sprecherin #Weidel kritisiert das von Bundeskanzler Olaf #Scholz kindisch als #Doppelwumms bezeichnete Entlastungsp…
# ['AfD-Sprecherin', 'kritisiert', 'das', 'von', 'Bundeskanzler', 'Olaf', 'kindisch', 'als', 'bezeichnete', 'Entlastungsp']
# Während #China mit deutscher Technik Rekorde feiert, wirtschaftet die #Ampel unser Land in allen Bereichen des Lebens herunter. Umlenken ist angesagt! #AfD #UnserLandzuerst
#
# https://t.co/b2s17T6BIK
# ['mit', 'deutscher', 'Technik', 'Rekorde', 'feiert', 'wirtschaftet', 'die', 'unser', 'Land', 'in', 'allen', 'Bereichen', 'des', 'Lebens', 'herunter', 'Umlenken', 'ist', 'angesagt']
# #Lauterbach (#SPD) kündigt bei #Lanz großspurig an, bis zu 8 Mrd. € aus dem „#Energiestabilisierungsfond“ zu nutzen. Eine Farce, bei der sich ein Verursacher der #Krise zum Retter aufschwingt - auf Kosten der #Steuerzahler!
#
# https://t.co/lrJZnWyZoQ #AfD #UnserLandzuerst https://t.co/8azHQmtcnL
# ['bei', 'grospurig', 'an', 'bis', 'zu', 'Mrd', 'aus', 'dem', 'zu', 'nutzen', 'Eine', 'Farce', 'bei', 'der', 'sich', 'ein', 'Verursacher', 'der', 'zum', 'Retter', 'aufschwingt', '-', 'auf', 'Kosten', 'der']
# RT @Alice_Weidel: Karl #Lauterbach verteilt großzügig #Steuergeld, ohne die Politik der #Bundesregierung zu hinterfragen. 8 Milliarden Euro…
# ['Karl', 'verteilt', 'grozgig', 'ohne', 'die', 'Politik', 'der', 'zu', 'hinterfragen', 'Milliarden', 'Euro']
# RT @Dennis_Hohloch: Deutsche "Umwelthilfe" (DUH):
# ❌Böllerverbot🎆
# ❌Keine Weihnachtsbeleuchtung🎄
# ❌Tempolimit
# ❌Keine Kohlekraftwerke
# ❌Diesel-F…
# ['Deutsche', 'Umwelthilfe', 'DUHBllerverbotKeine', 'WeihnachtsbeleuchtungTempolimitKeine', 'KohlekraftwerkeDiesel-F']
# RT @Alice_Weidel: Dass die Industrie ihre Produktion einstellt, ist den Medien eine Jubelmeldung wert. Kein Wort über tausende Arbeitsplätz…
# ['Dass', 'die', 'Industrie', 'ihre', 'Produktion', 'einstellt', 'ist', 'den', 'Medien', 'eine', 'Jubelmeldung', 'wert', 'Kein', 'Wort', 'ber', 'tausende', 'Arbeitspltz']
# RT @Tino_Chrupalla: Ampel uneins über #China-Strategie. Die Grünen um @ABaerbock und #Habeck trommeln für Wirtschaftskrieg. @Bundeskanzler…
# ['Ampel', 'uneins', 'ber', '-Strategie', 'Die', 'Grnen', 'um', 'ABaerbock', 'und', 'trommeln', 'fr', 'Wirtschaftskrieg', 'Bundeskanzler']
# #HabeckRuecktrittSofort #AfD #UnserLandZuerst https://t.co/WlSijQHuR3
# []
# RT @M_HarderKuehnel: Die Grenzen müssen vollumfänglich abgesichert und  illegale #Migranten vor Ort abgewiesen werden. Wir müssen die Reißl…
# ['Die', 'Grenzen', 'mssen', 'vollumfnglich', 'abgesichert', 'und', 'illegale', 'vor', 'Ort', 'abgewiesen', 'werden', 'Wir', 'mssen', 'die', 'Reil']
# RT @AfDimEUParl: ➡️ Gestehen Sie Ihr Scheitern endlich ein!
# Die Aufnahme der Balkanstaaten in die EU ist eine einzige Geschichte des Scheit…
# ['Gestehen', 'Sie', 'Ihr', 'Scheitern', 'endlich', 'einDie', 'Aufnahme', 'der', 'Balkanstaaten', 'in', 'die', 'EU', 'ist', 'eine', 'einzige', 'Geschichte', 'des', 'Scheit']
